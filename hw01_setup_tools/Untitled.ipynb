# %%
# %pip install -U numpy pandas matplotlib seaborn scikit-learn
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
ls
# Out:
# hw01_setup_tools.ipynb  README.md  Untitled.ipynb

# %%
cd ..
# Out:
# /home/weblov3/ml-course-homeworks

# %%
ls
# Out:
# hw01_setup_tools/  ml_dataset_20k.csv  requirements.txt  scooter_alerts.ipynb

# %%
df = pd.read_csv("ml_dataset_20k.csv")

# %%
df.head()
# Out:
#    incident_id  probability  is_real_incident       last_order_end  \
# 0        25744           70                 0  0001-01-01T00:00:00
# 1        25743            0                 0  0001-01-01T00:00:00
# 2        25741           70                 0  0001-01-01T00:00:00
# 3        25740           70                 0  0001-01-01T00:00:00
# 4        25739            0                 0  0001-01-01T00:00:00
#
#             after_order_start   gap_minutes  total_after_distance_km  \
# 0  2025-03-10T01:12:28.299000  1.064619e+09                    1.124
# 1  2025-03-10T18:12:55.712000  1.064620e+09                    0.022
# 2  2025-03-10T16:36:27.604000  1.064620e+09                    2.635
# 3  2025-03-10T12:00:00.595000  1.064620e+09                    5.898
# 4  2025-03-10T19:06:51.672000  1.064621e+09                    0.252
#
#    max_jump_distance_km  mean_speed_kmh  median_speed_kmh  ...  \
# 0                 0.135            0.08              0.04  ...
# ...

# %%
df.shape
# Out:
# (5938, 21)

# %%
df.describe()
# Out:
#         incident_id  probability  is_real_incident   gap_minutes  \
# count   5938.000000  5938.000000       5938.000000  5.938000e+03
# mean   22135.107107    19.676659          0.097676  1.064618e+09
# std     2109.704114    28.830670          0.296901  1.247905e+03
# min    18161.000000     0.000000          0.000000  1.064614e+09
# 25%    20486.250000     0.000000          0.000000  1.064617e+09
# 50%    22192.500000     0.000000          0.000000  1.064618e+09
# 75%    23935.750000    45.000000          0.000000  1.064619e+09
# max    25744.000000    75.000000          1.000000  1.064621e+09
#
#        total_after_distance_km  max_jump_distance_km  mean_speed_kmh  \
# count               5938.00000           5938.000000    5.938000e+03
# mean                 537.55116             63.966336    5.146006e+03
# std                 2376.51252            566.368036    1.710007e+05
# min                    0.00000              0.000000    0.000000e+00
# ...

# %%
df.isna().sum()
# Out:
# incident_id                     0
# probability                     0
# is_real_incident                0
# last_order_end                  0
# after_order_start               0
# gap_minutes                     0
# total_after_distance_km         0
# max_jump_distance_km            0
# mean_speed_kmh                  0
# median_speed_kmh                0
# max_speed_kmh                   0
# bearing_changes                 0
# static_segments_ratio           0
# radius_from_start_m             0
# coordinate_stability_m          0
# return_count                    0
# after_order_start_hour          0
# after_track_duration_minutes    0
# bearing_changes_ratio           0
# full_stop_count                 0
# linearity                       0
# dtype: int64
